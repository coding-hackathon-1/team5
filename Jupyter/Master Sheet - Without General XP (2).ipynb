# %%
import random as rd
import pandas as pd
import getpass as ps

# %%
app_list = []
df = pd.DataFrame()

# %%
def edu_email():
    email = input("Please enter your @student.hult.edu email: ")
    if '@student.hult.edu' in email: 
        return email
    else:
        return edu_email()

# %%
def new_user(): 
   
    email = str(edu_email())


    #---------------------------------------------------------------------------
    
    user_name = input("Enter your user name: ")
    pass_word = ps.getpass("Password: ")
    
    #---------------------------------------------------------------------------

    
                
    nation = input("What is your nationality? ")
    
    #---------------------------------------------------------------------------
    
    while True:
        
        lang_no = int(input("How many languages do you speak? (Max 5) "))
    
        if lang_no == 1:
            lang_1 = input("What language do you speak? ")
            lang_2 = ""
            lang_3 = ""
            lang_4 = ""
            lang_5 = ""
            break
        
        elif lang_no == 2:
            lang_1 = input("What language do you speak? ")
            lang_2 = input("What is the second language you speak? ")
            lang_3 = ""
            lang_4 = ""
            lang_5 = ""
            break
        
        elif lang_no == 3:
            lang_1 = input("What language do you speak? ")
            lang_2 = input("What is the second language you speak? ")
            lang_3 = input("What is the third language you speak? ")
            lang_4 = ""
            lang_5 = ""
            break
        
        elif lang_no == 4:
            lang_1 = input("What language do you speak? ")
            lang_2 = input("What is the second language you speak? ")
            lang_3 = input("What is the third language you speak? ")
            lang_4 = input("What is the fourth language you speak? ")
            lang_5 = ""
            break
        
        else:
            lang_1 = input("What language do you speak? ")
            lang_2 = input("What is the second language you speak? ")
            lang_3 = input("What is the third language you speak? ")
            lang_4 = input("What is the fourth language you speak? ")
            lang_5 = input("What is the fifth language you speak? ")
            break
            
    #---------------------------------------------------------------------------
    
    
    app_list.append({"user_name" : user_name,
                     "password" : pass_word,
                     "email" : email,
                     "nation" : nation,
                     "lang_no" : lang_no,
                     "lang_1" : lang_1,
                     "lang_2" : lang_2,
                     "lang_3" : lang_3,
                     "lang_4" : lang_4,
                     "lang_5" : lang_5})
    

    print("Account Created")

# %%
def old_user():
    user_name = input("Enter your user name: ")
    pass_word = ps.getpass("Password: ")
    #if u_name == user_data['username']: #and pswd == user_data['password']:
    
    while True:
        if str(user_name) in str(user_data['user_name']) and str(pass_word) in str(user_data['password']):
            print(f"Login successful, Welcome back {user_name}!")
            break
    
        else:
            print("Invalid login, please try again.")
            return old_user()
        
    #else:
        #print("User doesn't exist or wrong password!")

# %%
#defining if user is new or old
#def login():
while True:
    user = input("""  
    If you are an existing user, input 'Log In'

    If you are a new user, input 'Register'  

    """)

    if user.lower() == "register" :
        new_user()
        user_data = df.append(app_list, ignore_index = True)
        user_data = user_data.reindex(columns = ['user_name', 'password', 'email', 'nation', 'lang_no', 'lang_1', "lang_2", "lang_3", "lang_4", "lang_5"])
        user_data.to_excel('user_data.xlsx')
        break


    elif user.lower() == "log in":
        old_user()
        break


    else:
        print("Wrong input! Please enter 'Log In' or 'Register'")
# Out:
#
#     If you are an existing user, input 'Log In'
#
#     If you are a new user, input 'Register'
#
#     register
# Please enter your @student.hult.edu email: marcelo@student.hult.edu
# Enter your user name: ghjk
# Password: ········
# What is your nationality? ghjksksk
# How many languages do you speak? (Max 5) 2
# What language do you speak? ghjk
# What is the second language you speak? hrhej
# Account Created

# %%
user_data
# Out:
#   user_name password                     email    nation  lang_no lang_1  \
# 0      ghjk    ghjkl  marcelo@student.hult.edu  ghjksksk        2   ghjk
#
#   lang_2 lang_3 lang_4 lang_5
# 0  hrhej

# %%
app_list
# Out:
# [{'user_name': 'ghjk',
#   'password': 'ghjkl',
#   'email': 'marcelo@student.hult.edu',
#   'nation': 'ghjksksk',
#   'lang_no': 2,
#   'lang_1': 'ghjk',
#   'lang_2': 'hrhej',
#   'lang_3': '',
#   'lang_4': '',
#   'lang_5': ''}]

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Trivia Questions (!!!!!!!)

personal_xp = 0
cohort = input("""
Hello! We are so excited that you are in Hult!
We are very proud of our student body and how diverse it is!
We want you to expand your knowledge about the world.
Here are some trivia questions for you in exchange of XP's for you and your cohort!
       
What is your Cohort? Blue or Green or Yellow or Red? >>  """)
if cohort.lower == 'blue':
    print(f"""\n Great, welcome member of the {cohort} team""")
elif cohort.lower == 'green':
    print(f"""\n Great, welcome member of the {cohort} team""")
elif cohort.lower == 'yellow':
    print(f"""\n Great, welcome member of the {cohort} team""")
elif cohort.lower == 'red':
    print(f"""\n Great, welcome member of the {cohort} team""")
else: 
    cohort = input("please input \"Blue\" or \"Green\" or \"Yellow\" or \"Red\">>  ")
  
#-------------------------------------------------------------------------------------------------------
quest_1 = input( """ \n
*Question 1*
Which of this is not a continent? 
       a. North America
       b. Southern Africa
       c. Oceania
       d. Asia \n \n 
       Answer >>  """)

#make input lower case
quest_1 = quest_1.lower()                    
if quest_1 == 'b':
    print("\n Amazing!")
    personal_xp += 5
else:
    print("\n It is b! South Africa* is a country not a continent.\n")
#-------------------------------------------------------------------------------------------------------
input("\nPress enter for next question")

#-------------------------------------------------------------------------------------------------------
quest_2 = input( """ \n 
*Question 2*
Is Antartica a country?
Hmm, I remember I saw a picture of their capital "Iglü"
       a. yes
       b. no
       
       Answer >> """)

#make input lower case
quest_2 = quest_2.lower()
if quest_2 == 'b':
    print("Great!")
    personal_xp += 5
else:
    print("Where did you see that? Antartica is a continent, not a country!")
    
#-------------------------------------------------------------------------------------------------------   
input("\nPress enter for next question")   
    
#-------------------------------------------------------------------------------------------------------
quest_3 = input( """ \n
*Question 3*
Jakarta is obviously in Asia, just as Juba, right?
Is Juba in Asia?
       a. duh
       b. wtf, no 
       
       Answer >> """)

#make input lower case
quest_3 = quest_3.lower()            
if quest_3 == 'b':
    print("\n Great!")
    personal_xp += 5
else:
    print("\n It is not! Juba is the capital of South Sudan, Africa!") 


#-------------------------------------------------------------------------------------------------------   
input("\nPress enter for next question")   
    
#-------------------------------------------------------------------------------------------------------
quest_4 = input( """ \n 
*Question 4*
Which is the only country to play in every World Cup?
         a. Germany
         b. Current Champs, France
         c. Brasil
         d. Netherlands
                
        Answer >> """)

#make input lower case
quest_4 = quest_4.lower()
if quest_4 == 'c':
    print("Great!")
    personal_xp += 5
else:
    print("Netherlands never misses a World Cup!")
 
 
#-------------------------------------------------------------------------------------------------------   
input("\nPress enter for next question")   
    
#-------------------------------------------------------------------------------------------------------
quest_5 = input("""\n 
*Question 5*
What is the capital city of Singapore?
        a. Tampines
        b. Jakarta
        c. Kuala Lumpur
        d. Singapore 
        
        Answer >> """)

#make input lower case
quest_5 = quest_5.lower()
if quest_5 == 'd':
    print("Great!")
    personal_xp += 5
else:
    print("Singapore is the capital city of Singapore!")
    
#-------------------------------------------------------------------------------------------------------   
input("\nPress enter for next question")   
    
#-------------------------------------------------------------------------------------------------------
quest_6 = input("""\n \n 
*Question 6*
Where is Papua New Guinea?
       a. West Africa
       b. South America
       c. Oceania
       d. Asia 
       
       Answer >> """)
                      
#make input lower case
quest_6 = quest_6.lower()
if quest_6 == 'c':
    print("Great!")
    personal_xp += 5
else:
    print("Papua New Guinea is on top of Australia, beside Indonesia!")  
    
print(f"Current Score is {personal_xp}!!")
# Out:
# Hello! We are so excited that you are in Hult!
# We are very proud of our student body and how diverse it is!
# We want you to expand your knowledge about the world.
# Here are some trivia questions for you in exchange of XP's for you and your cohort!
#
# What is your Cohort? Blue or Green or Yellow or Red? >>  yellow
# please input "Blue" or "Green" or "Yellow" or "Red">>  red
#
#
# *Question 1*
# Which of this is not a continent?
#        a. North America
#        b. Southern Africa
#        c. Oceania
#        d. Asia
#
#
#        Answer >>  d
#
#  It is b! South Africa* is a country not a continent.
#
#
# Press enter for next question
#
#
# *Question 2*
# Is Antartica a country?
# Hmm, I remember I saw a picture of their capital "Iglü"
#        a. yes
#        b. no
#
#        Answer >> b
# Great!
#
# Press enter for next question
#
#
# *Question 3*
# Jakarta is obviously in Asia, just as Juba, right?
# Is Juba in Asia?
#        a. duh
#        b. wtf, no
#
#        Answer >> b
#
#  Great!
#
# Press enter for next question
#
#
# *Question 4*
# Which is the only country to play in every World Cup?
#          a. Germany
#          b. Current Champs, France
#          c. Brasil
#          d. Netherlands
#
#         Answer >> c
# Great!
#
# Press enter for next question
#
#
# *Question 5*
# What is the capital city of Singapore?
#         a. Tampines
#         b. Jakarta
#         c. Kuala Lumpur
#         d. Singapore
#
#         Answer >> d
# Great!
#
# Press enter for next question
#
#
#
# *Question 6*
# Where is Papua New Guinea?
#        a. West Africa
#        b. South America
#        c. Oceania
#        d. Asia
#
#        Answer >> c
# Great!
# Current Score is 25!!
